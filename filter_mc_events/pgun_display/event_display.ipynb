# %%
import display_utils
import importlib
importlib.reload(display_utils)

# %%
# records = display_utils.load_files("/home/yousen/Documents/NDLAr2x2/MuonLArSim/build/pgun_mu_3GeV_merged.hdf5")
#edit 20250722
records = display_utils.load_files("/home/yousen/Documents/NDLAr2x2/MuonLArSim/build/pgun_mu_3GeV_2mm_merged_hits.hdf5")

# %%
display_utils.interactive_browser_k3d(records)
