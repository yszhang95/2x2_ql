# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f = np.load("single_track_for_sp_pid13_angle30.npz")

# %%
f.files

# %%
f['effq_tpc5_batch0'].shape

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Generate sample data
x = f['effq_tpc5_batch0'][:,0]
y = f['effq_tpc5_batch0'][:,1]
z = f['effq_tpc5_batch0'][:,2]
c = f['effq_tpc5_batch0'][:,3]

# Create 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x, y, z, c=c, marker='o')

# Labels
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Generate sample data
x = f['hits_tpc5_batch0'][:,0]
y = f['hits_tpc5_batch0'][:,1]
z = f['hits_tpc5_batch0'][:,2]
c = f['hits_tpc5_batch0'][:,3]

# Create 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
ax.scatter(x, y, z, c=c, marker='o')

# Labels
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')

plt.show()

# %%
plt.scatter(x = f['hits_tpc5_batch0'][:,1], y = f['hits_tpc5_batch0'][:,2])

# %%
plt.scatter(x = f['effq_tpc5_batch0'][:,1], y = f['effq_tpc5_batch0'][:,2])

# %%
plt.scatter(x = f['effq_tpc5_batch0_location'][:,0], y = f['effq_tpc5_batch0_location'][:,1])

# %%
plt.scatter(x = f['effq_fine_grain_tpc5_batch0_location'][:,0], y = f['effq_fine_grain_tpc5_batch0_location'][:,1])
